# %% [markdown]
# ## Se importan las librerias a utilizar

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Leemos los archivos respectivos

# %%
hechos = pd.read_csv('../Data/CSV/hechos_homicidios.csv')
victimas = pd.read_csv('../Data/CSV/victimas_homicidios.csv')

# %%
edades = sns.histplot(data = victimas, x = victimas['EDAD'], bins=10,color='r',shrink=.8)
edades.set_xlabel('Edades')
edades.set_ylabel('Victimas')
# Out:
# Text(0, 0.5, 'Victimas')

# %% [markdown]
# Segun esta grafica podemos observar que las personas que tienen entre 20 y 30 años se accidentan mas

# %%
horas = sns.histplot(data = hechos, x = hechos['HH'], bins=24,color='g',shrink=.8)
horas.set_xlabel('Horas')
horas.set_ylabel('Accidentes')
# Out:
# Text(0, 0.5, 'Accidentes')

# %% [markdown]
# En esta grafica podemos observar que los horarios con mas concentracion de accidentes son los horarios de la mañana

# %%
masculino = victimas['ID_SEXO'].value_counts()['M']
femenino = victimas['ID_SEXO'].value_counts()['F']

etiquetas = 'Masculino', 'Femenino'
sizes = [masculino, femenino]

ax = plt.subplot()
ax.pie(sizes, labels=etiquetas, autopct='%1.1f%%',colors=['g', 'b'],shadow=True, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x2493f1f37a0>,
# ...
#  [Text(-0.7364047331254393, -0.8171340581755546, 'Masculino'),
#   Text(0.7364046566198242, 0.8171341271227379, 'Femenino')],
#  [Text(-0.4016753089775123, -0.4457094862775752, '76.7%'),
#   Text(0.4016752672471768, 0.44570952388512974, '23.3%')])

# %% [markdown]
# Segun este grafico de torta podemos ver que el genero masculino tiende a accidentarse mucho mas que las mujeres
